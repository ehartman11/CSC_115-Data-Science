# %%
import pandas as pd

df = pd.read_csv('Fast-Food Chains in USA.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Fast-Food Chains                                  50 non-null     object
#  1   U.S. Systemwide Sales (Millions - U.S Dollars)    50 non-null     int64
#  2   Average Sales per Unit (Thousands - U.S Dollars)  50 non-null     int64
#  3   Franchised Stores                                 50 non-null     int64
#  4   Company Stores                                    50 non-null     int64
#  5   2021 Total Units                                  50 non-null     int64
#  6   Total Change in Units from 2020                   50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB
# None

# %%
# Using pandas to insert a new record into the dataset with the following details:
# Fast-Food Chain: "Subway", Systemwide Sales: $1000 million, Average Sales per Unit: $400 thousand,
# Franchised Stores: 2000, Company Stores: 500, 2021 Total Units: 2500, Total Change in Units from 2020: 50
df.loc[len(df)] = ['Subway', 1000, 400, 2000, 500, 2500, 50]
df.tail()
# Out:
#    Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 46      Whataburger                                            3089
# 47     White Castle                                             615
# 48         Wingstop                                            2278
# 49          Zaxby’s                                            2233
# 50           Subway                                            1000
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 46                                              3640                131
# 47                                              1749                  0
# 48                                              1592               1498
# 49                                              2484                761
# 50                                               400               2000
#
#     Company Stores  2021 Total Units  Total Change in Units from 2020
# ...

# %%
# Update the systemwide sales for the fast food chain with the name "McDonald's" to $40000 million.
index = df[df['Fast-Food Chains'] == "McDonald’s"].index
df.at[index[0], 'U.S. Systemwide Sales (Millions - U.S Dollars)'] = 40000
df
# Out:
#                           Fast-Food Chains  \
# 0                                   Arby’s
# 1                           Baskin-Robbins
# 2                                Bojangles
# 3                              Burger King
# 4                               Carl’s Jr.
# 5                         Checkers/Rally’s
# 6                              Chick-fil-A
# 7                                 Chipotle
# 8                         Church’s Chicken
# 9                                 Culver’s
# 10                             Dairy Queen
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy’s Frozen Custard & Steakburgers
# 18                                Hardee’s
# 19                         In-N-Out Burger
# 20                         Jack in the Box
# ...

# %%
# Using pandas to calculate the average systemwide sales for each category of fast food chains, grouped by category.
df.groupby('Fast-Food Chains')['U.S. Systemwide Sales (Millions - U.S Dollars)'].mean()
# Out:
# Fast-Food Chains
# Arby’s                                     4462.0
# Baskin-Robbins                              686.0
# Bojangles                                  1485.0
# Burger King                               10033.0
# Carl’s Jr.                                 1560.0
# Checkers/Rally’s                            931.0
# Chick-fil-A                               16700.0
# Chipotle                                   7547.0
# Church’s Chicken                            776.0
# Culver’s                                   2489.0
# Dairy Queen                                4494.0
# Del Taco                                    931.0
# Domino's                                   8641.0
# Dunkin'                                   10416.0
# El Pollo Loco                               973.0
# Firehouse Subs                             1044.0
# Five Guys                                  2093.0
# Freddy’s Frozen Custard & Steakburgers      759.0
# ...

# %%
# Using pandas retrieve the top 10 fast food chains with the highest average sales per unit, 
ordered by average sales per unit in descending order.
top_sales = df.sort_values(by='Average Sales per Unit (Thousands - U.S Dollars)', ascending=False)
top_sales.head(10)
# Out:
#   Cell In[5], line 2
#     ordered by average sales per unit in descending order.
#             ^
# SyntaxError: invalid syntax

# %%
# Using pandas retrieve the names of all fast food chains that have more franchised stores than company stores.
fran_grp = df[df['Franchised Stores'] > df['Company Stores']]['Fast-Food Chains']
fran_grp
# Out:
# 0                                     Arby’s
# 1                             Baskin-Robbins
# 2                                  Bojangles
# 3                                Burger King
# 4                                 Carl’s Jr.
# 5                           Checkers/Rally’s
# 6                                Chick-fil-A
# 8                           Church’s Chicken
# 9                                   Culver’s
# 10                               Dairy Queen
# 11                                  Del Taco
# 12                                  Domino's
# 13                                   Dunkin'
# 14                             El Pollo Loco
# 15                            Firehouse Subs
# 16                                 Five Guys
# 17    Freddy’s Frozen Custard & Steakburgers
# 18                                  Hardee’s
# 20                           Jack in the Box
# 21                             Jersey Mike’s
# 22                              Jimmy John’s
# ...

# %%
# Using pandas delete all records from the dataset where the total change in units from 2020 is negative.
df.drop(df[df['Total Change in Units from 2020'] < 0].index)
# Out:
#                           Fast-Food Chains  \
# 0                                   Arby’s
# 1                           Baskin-Robbins
# 2                                Bojangles
# 3                              Burger King
# 6                              Chick-fil-A
# 7                                 Chipotle
# 9                                 Culver’s
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy’s Frozen Custard & Steakburgers
# 19                         In-N-Out Burger
# 21                           Jersey Mike’s
# 22                            Jimmy John’s
# 23                                     KFC
# 24                            Krispy Kreme
# 26                           Marco’s Pizza
# 27                        McAlister’s Deli
# ...
